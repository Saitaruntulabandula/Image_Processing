# %% [markdown]
# # Importing Libraries

# %%
import cv2
import numpy as np
import skimage as io
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
#For Black and White Image.
#Images are stored in the form of Matrix of Numbers in a Computer.
#These numbers are know as Pixel values.
#Ranges from 0-255 where 0 is for Black and 255 is for White.
#These Matrix of Numbers is Known as Channel.
#Dimension x*y=1024*768 (No of Pixels across the Height*Width)

# %%
#For Colour Images.
#All colours will gets generated by the 3 primary colours(Red,Green,Blue).
#For coloured images we had 3 Matrices which are Red,Green,Blue Channels.

# %%
# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8

# read images
img_A = mpimg.imread('img.png')
img_B = mpimg.imread('img1.png')

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_A)
ax[1].imshow(img_B)

# %%
# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8

# read images
img_C = mpimg.imread('img2.png')
img_D = mpimg.imread('img3.png')

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_C)
ax[1].imshow(img_D)

# %% [markdown]
# # Importing Random Image

# %%
random_image=np.random.random([500,500])
plt.imshow(random_image)

# %%
print(random_image.shape)
# Out:
# (500, 500)

# %%
print(random_image)
# Out:
# [[0.50763808 0.90653834 0.90117081 ... 0.42938489 0.64204549 0.08903795]
#  [0.34183038 0.17300839 0.71256588 ... 0.38637563 0.40528724 0.51736937]
#  [0.6284816  0.39213873 0.06717275 ... 0.26544798 0.42234371 0.48688808]
#  ...
#  [0.12280065 0.92427166 0.57520529 ... 0.02500857 0.40464039 0.01738164]
#  [0.03283867 0.21338965 0.57444696 ... 0.95485944 0.57840163 0.22422492]
#  [0.78327309 0.96112513 0.39359863 ... 0.47852071 0.06205894 0.39919733]]

# %%
print(random_image.min(),random_image.max())
# Out:
# 2.858768785030108e-07 0.9999864704350375

# %% [markdown]
# # Importing Image

# %%
my_img = cv2.imread("Image.jpg")

# %%
plt.imshow(my_img)                                #Printing Image.

# %%
my_img        #Numpy array
# Out:
# array([[[128, 124,  89],
#         [128, 124,  89],
#         [129, 125,  90],
#         ...,
#         [143, 140, 126],
#         [142, 139, 125],
#         [143, 140, 126]],
#
#        [[133, 129,  94],
#         [133, 129,  94],
#         [132, 128,  93],
#         ...,
#         [142, 139, 125],
#         [140, 137, 123],
#         [141, 138, 124]],
#
#        [[132, 128,  93],
#         [132, 128,  93],
#         [132, 128,  93],
#         ...,
#         [141, 138, 123],
#         [141, 138, 124],
#         [142, 139, 125]],
#
#        ...,
#
#        [[ 40,  41,  45],
#         [ 38,  39,  43],
#         [ 35,  36,  40],
#         ...,
#         [ 21,  22,  18],
#         [ 20,  21,  17],
#         [ 20,  21,  17]],
#
#        [[ 36,  36,  42],
#         [ 36,  36,  42],
#         [ 33,  36,  41],
#         ...,
#         [ 20,  21,  17],
#         [ 20,  21,  17],
#         [ 20,  22,  16]],
#
#        [[ 33,  33,  39],
#         [ 34,  34,  40],
#         [ 33,  35,  43],
# ...

# %%
print(my_img.min(),my_img.max())                     #The numbers in the image will go from 0-226(Image Pixel Vales).
# Out:
# 0 226

# %% [markdown]
# # Converting into float

# %%
from skimage import img_as_float

# %%
float_img=img_as_float(my_img)

# %%
plt.imshow(float_img)

# %%
print(float_img)
# Out:
# [[[0.50196078 0.48627451 0.34901961]
#   [0.50196078 0.48627451 0.34901961]
#   [0.50588235 0.49019608 0.35294118]
#   ...
#   [0.56078431 0.54901961 0.49411765]
#   [0.55686275 0.54509804 0.49019608]
#   [0.56078431 0.54901961 0.49411765]]
#
#  [[0.52156863 0.50588235 0.36862745]
#   [0.52156863 0.50588235 0.36862745]
#   [0.51764706 0.50196078 0.36470588]
#   ...
#   [0.55686275 0.54509804 0.49019608]
#   [0.54901961 0.5372549  0.48235294]
#   [0.55294118 0.54117647 0.48627451]]
#
#  [[0.51764706 0.50196078 0.36470588]
#   [0.51764706 0.50196078 0.36470588]
#   [0.51764706 0.50196078 0.36470588]
#   ...
#   [0.55294118 0.54117647 0.48235294]
#   [0.55294118 0.54117647 0.48627451]
#   [0.55686275 0.54509804 0.49019608]]
#
#  ...
#
#  [[0.15686275 0.16078431 0.17647059]
#   [0.14901961 0.15294118 0.16862745]
#   [0.1372549  0.14117647 0.15686275]
#   ...
#   [0.08235294 0.08627451 0.07058824]
#   [0.07843137 0.08235294 0.06666667]
#   [0.07843137 0.08235294 0.06666667]]
#
# ...

# %%
print(float_img.min(),float_img.max())                  #The numbers in the image will go from 0-226(Image Pixel Vales).
# Out:
# 0.0 0.8862745098039215

# %% [markdown]
# # Replacing the Pixels

# %%
plt.imshow(my_img)                                      #Printing Image.

# %%
print(my_img.min(),my_img.max())                        #The numbers in the image will go from 0-226(Image Pixel Vales).
# Out:
# 0 226

# %%
my_img[100:800,100:800,:]=[255,0,0]

# %%
plt.imshow(my_img)

# %%
my_img[100:800,100:800,:]=[0,255,0]

# %%
plt.imshow(my_img)

# %%
my_img[100:800,100:800,:]=[0,0,255]

# %%
plt.imshow(my_img)

# %%
my_img[100:800,100:800,:]=[255,255,0]               #Red+Green

# %%
plt.imshow(my_img)

# %%
my_img[100:800,100:800,:]=[255,0,255]               #Red+Blue

# %%
plt.imshow(my_img)

# %%
my_img[100:800,100:800,:]=[0,255,255]               #Green+Blue

# %%
plt.imshow(my_img)

# %%
my_img[100:800,100:800,:]=[255,255,255]             #Red+Green+Blue

# %%
plt.imshow(my_img)

# %% [markdown]
# # Detection by template matching

# %%
img_rgb=cv2.imread("Image.png")

# %%
img_gray=cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)

# %%
template=cv2.imread("Template.png",0)

# %%
h,w = template.shape[::]

# %%
res=cv2.matchTemplate(img_gray,template,cv2.TM_SQDIFF)

# %%
plt.imshow(res,cmap="gray")

# %%
min_val,max_val,min_loc,max_loc=cv2.minMaxLoc(res)

# %%
top_left=min_loc

# %%
bottom_right=(top_left[0]+w,top_left[1]+h)

# %%
cv2.rectangle(img_gray,top_left,bottom_right,255,2)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
cv2.imshow("Matched Image",img_gray)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print(template.dtype)
# Out:
# uint8

# %%
cv2.imshow("Template", template)
cv2.imshow("Image", image)
cv2.waitKey()
# Out:
# -1

# %%
import cv2
import numpy as np

# Read the input and template image
img = cv2.imread("Image.png")
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
template = cv2.imread('Template.png',0)
w, h = template.shape[::-1]

# Apply template matching
res = cv2.matchTemplate(img_gray,template,cv2.TM_CCOEFF_NORMED)

# Threshold the result
threshold = 0.95
loc = np.where(res >= threshold)

# Draw the rectangle
for pt in zip(*loc[::-1]):
    cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (255,0,0), 1)

# Display the result
cv2.imshow('a',img)
cv2.waitKey(0)
# Out:
# -1

# %%
result = cv2.matchTemplate(image, template, method[, mask]])

# image: must be 8-bit or 32-bit floating-point
# template: should have size less than input image and same data type
# method: Comparison method to be used. See the table above
# mask: Optional mask. must have same size as template. If data type is CV_32F, then values treated as weights otherwise treat it as the traditional mask.
# result: comparison result. single-channel 32-bit floating-point. If image is W×H and templ is w×h , then result is (W−w+1)×(H−h+1)

# %% [markdown]
# # Image Segmentation

# %%
# Python program to transform an image using
# threshold.
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Image operation using thresholding
img = cv2.imread('coin-detection.jpg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret, thresh = cv2.threshold(gray, 0, 255,cv2.THRESH_BINARY_INV +cv2.THRESH_OTSU)
plt.imshow(img)
plt.imshow(thresh, cmap='gray')

# %%
# Noise removal using Morphological
# closing operation
kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE,kernel, iterations = 2)

# Background area using Dilation
bg = cv2.dilate(closing, kernel, iterations = 1)

# Finding foreground area
dist_transform = cv2.distanceTransform(closing, cv2.DIST_L2, 0)
ret, fg = cv2.threshold(dist_transform, 0.02* dist_transform.max(), 255, 0)

plt.imshow(fg, cmap='gray')
